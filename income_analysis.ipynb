# %%
import pandas as pd

df = pd.read_csv("data-income.csv")

# %%
df.head(5)
# Out:
#    p80_to_p20_ratio   median_aud   highest_quartile_pc   income_aud  \
# 0              4.46        49482                  26.7   3085268445
# 1              4.65        53084                  30.2   2077431108
# 2              4.97        54714                  32.3   2826293930
# 3              6.22        47298                  27.8   4995364989
# 4              4.96        58932                  35.7   5749953970
#
#     income_share_top_5pc   median_age_of_earners_years   third_quartile_pc  \
# 0                   18.3                            36                25.8
# 1                   20.5                            39                25.7
# 2                   22.7                            40                24.5
# 3                   28.6                            32                22.5
# 4                   27.3                            37                24.6
#
#     earners_persons   lowest_quartile_pc   mean_aud   p20_to_p50_ratio  \
# ...

# %%
income_data = df[[' mean_aud', ' sa3_name16']]

# %%
income_data
# Out:
#     mean_aud          sa3_name16
# 0      59872  Brunswick - Coburg
# 1      67311     Darebin - South
# 2      71898            Essendon
# 3      68949      Melbourne City
# 4      84064        Port Phillip
# 5     106719  Stonnington - West
# 6      76312               Yarra

# %%
import json
income_dict = {"CARLTON NORTH":2039, "CARLTON":1869, "DOCKLANDS":1868, "EAST MELBOURNE":2285, "FLEMINGTON":1171,
              "KENSINGTON":1956, "MELBOURNE":1148, "NORTH MELBOURNE":1236, "PARKVILLE":1610, "PORT MELBOURNE":2190,
              "SOUTH WHARF":3250, "SOUTH YARRA":2000, "SOUTH BANK":1851, "WEST MELBOURNE":1766}

with open('dis_income.json', "w") as file:
    json.dump(income_dict, file)
